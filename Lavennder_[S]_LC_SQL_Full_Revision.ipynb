# %% [markdown]
# # Exercices sur les tables "customers" et "employee" de la base de données "toys_and_models"
#
# N.B : Suivez les consignes afin de pouvoir exécuter vos requetes SQL

# %% [markdown]
# # Introduction
#
# SQL est fondé sur une architecture client-serveur.
#
# Python est capable de se connecter à toutes les bases de données SQL (Oracle, MySQL, Microsoft, etc.).
#
# SQLite est un cas un peu particulier : il s'agit d'un petit fichier qui peut assumer le rôle de serveur, sans nécessité de nom d'utilisateur ni de mot de passe. Ceci sera utile pour cette série d'exercices.
#
# Cependant, gardez à l'esprit que vous pourriez connecter votre script Python à d'autres bases de données en suivant les mêmes étapes.

# %%
                               ################ Executer cette cellule OBLIGATOIREMENT #################

# Ici, nous importons simplement le fichier SQLite. Cette partie est spécifique à SQLite.
import requests
import sqlite3
import pandas as pd

# Envoyer une requête HTTP GET à l'URL spécifiée pour récupérer le fichier SQLite sur GitHub
r = requests.get('https://raw.githubusercontent.com/murpi/wilddata/master/quests/toys_and_models.sqlite')

# Cela télécharge et sauvegarde essentiellement le fichier SQLite localement nommé 'toys_and_models.sqlite' en mode écriture binaire ('wb') et
# permet d'y accèder sur ton environnement Google Colab.
open('toys_and_models.sqlite', 'wb').write(r.content)

# Ceci est le "connecteur". Pour une base de données sécurisée, c'est ici que vous indiquerez votre nom d'utilisateur et votre mot de passe.
conn = sqlite3.connect('toys_and_models.sqlite')

# %%
                     ################ Ceci est l'exemple à suivre pour exécuter vos requetes #################

# Voici un exemple de requête sql. La requête SQL est entre guillemets pour le premier argument, puis la variable conn en second argument.
pd.read_sql("select * from productlines", conn)
# Out:
#         productLine                                    textDescription  \
# 0      Classic Cars  Attention car enthusiasts: Make your wildest c...
# 1       Motorcycles  Our motorcycles are state of the art replicas ...
# 2            Planes  Unique, diecast airplane and helicopter replic...
# 3             Ships  The perfect holiday or anniversary gift for ex...
# 4            Trains  Model trains are a rewarding hobby for enthusi...
# 5  Trucks and Buses  The Truck and Bus models are realistic replica...
# 6      Vintage Cars  Our Vintage Car models realistically portray a...
#
#   htmlDescription image
# 0            None  None
# 1            None  None
# 2            None  None
# 3            None  None
# 4            None  None
# 5            None  None
# 6            None  None

# %% [markdown]
# ## Voici le schéma de la base de donnée qu'on va utiliser pour la suite de ces exercices

# %% [markdown]
# ![Texte alternatif…](https://mysqltutorial.org/wp-content/uploads/2009/12/MySQL-Sample-Database-Schema.png)

# %% [markdown]
# # BEGINNER LEVEL

# %% [markdown]
# **Tâche 1:** Récupérez tous les noms des clients et leurs numéros de téléphones

# %%
pd.read_sql("select customerName, phone from customers;", conn)
# Out:
#                        customerName           phone
# 0                 Atelier graphique      40.32.2555
# 1                Signal Gift Stores      7025551838
# 2        Australian Collectors, Co.    03 9520 4555
# 3                 La Rochelle Gifts      40.67.8555
# 4                Baane Mini Imports      07-98 9555
# ..                              ...             ...
# 117    Motor Mint Distributors Inc.      2155559857
# 118        Signal Collectibles Ltd.      4155554312
# 119  Double Decker Gift Stores, Ltd  (171) 555-7555
# 120            Diecast Collectables      6175552555
# 121                Kellys Gift Shop   +64 9 5555500
#
# [122 rows x 2 columns]

# %% [markdown]
# **Tâche 2:** Retrieve all customers located in the USA.

# %%
pd.read_sql("?;", conn)

# %%
pd.read_sql('SELECT * FROM customers WHERE 	country = "USA"', conn)
# Out:
#     customerNumber                  customerName contactLastName  \
# 0              112            Signal Gift Stores            King
# 1              124  Mini Gifts Distributors Ltd.          Nelson
# 2              129               Mini Wheels Co.          Murphy
# 3              131             Land of Toys Inc.             Lee
# 4              151            Muscle Machine Inc           Young
# 5              157         Diecast Classics Inc.           Leong
# 6              161          Technics Stores Inc.       Hashimoto
# 7              168        American Souvenirs Inc          Franco
# 8              173    Cambridge Collectables Co.           Tseng
# 9              175               Gift Depot Inc.            King
# 10             181               Vitachrome Inc.           Frick
# 11             198       Auto-Moto Classics Inc.          Taylor
# 12             204      Online Mini Collectables         Barajas
# 13             205             Toys4GrownUps.com           Young
# 14             219             Boards & Toys Co.           Young
# 15             239  Collectable Mini Designs Co.        Thompson
# 16             286           Martas Replicas Co.       Hernandez
# 17             319                 Mini Classics           Frick
# 18             320           Mini Creations Ltd.           Huang
# 19             321      Corporate Gift Ideas Co.           Brown
# 20             328       Tekni Collectables Inc.           Brown
# 21             339       Classic Gift Ideas, Inc       Cervantes
# 22             347      Men R US Retailers, Ltd.        Chandler
# 23             362             Gifts4AllAges.com         Yoshido
# 24             363  Online Diecast Creations Co.           Young
# 25             379    Collectables For Less Inc.          Nelson
# 26             424          Classic Legends Inc.       Hernandez
# 27             447              Gift Ideas Corp.           Lewis
# 28             450     The Sharp Gifts Warehouse           Frick
# 29             455              Super Scale Inc.          Murphy
# 30             456               Microscale Inc.            Choi
# 31             462              FunGiftIdeas.com         Benitez
# 32             475   West Coast Collectables Co.        Thompson
# 33             486  Motor Mint Distributors Inc.         Salazar
# 34             487      Signal Collectibles Ltd.          Taylor
# 35             495          Diecast Collectables          Franco
#
#    contactFirstName       phone               addressLine1 addressLine2  \
# 0              Jean  7025551838            8489 Strong St.         None
# 1             Susan  4155551450            5677 Strong St.         None
# 2             Julie  6505555787  5557 North Pendale Street         None
# 3              Kwai  2125557818    897 Long Airport Avenue         None
# 4              Jeff  2125557413          4092 Furth Circle    Suite 400
# 5            Kelvin  2155551555           7586 Pompton St.         None
# 6              Juri  6505556809          9408 Furth Circle         None
# 7             Keith  2035557845          149 Spinnaker Dr.    Suite 101
# 8             Jerry  6175555555             4658 Baden Av.         None
# 9             Julie  2035552570        25593 South Bay Ln.         None
# 10          Michael  2125551500          2678 Kingston Rd.    Suite 101
# 11           Leslie  6175558428          16780 Pompton St.         None
# 12           Miguel  6175557555         7635 Spinnaker Dr.         None
# 13            Julie  6265557265         78934 Hillside Dr.         None
# 14             Mary  3105552373           4097 Douglas Av.         None
# 15          Valarie  7605558146           361 Furth Circle         None
# 16            Marta  6175558555        39323 Spinnaker Dr.         None
# 17            Steve  9145554562  3758 North Pendale Street         None
# 18             Wing  5085559555          4575 Hillside Dr.         None
# 19            Julie  6505551386            7734 Strong St.         None
# 20          William  2015559350              7476 Moss Rd.         None
# 21        Francisca  2155554695           782 First Street         None
# 22            Brian  2155554369           6047 Douglas Av.         None
# 23             Juri  6175559555         8616 Spinnaker Dr.         None
# 24          Dorothy  6035558647   2304 Long Airport Avenue         None
# 25            Allen  6175558555           7825 Douglas Av.         None
# 26            Maria  2125558493           5905 Pompton St.    Suite 750
# 27              Dan  2035554407           2440 Pompton St.         None
# 28              Sue  4085553659             3086 Ingle Ln.         None
# 29           Leslie  2035559545   567 North Pendale Street         None
# 30               Yu  2125551957  5290 North Pendale Street    Suite 200
# 31          Violeta  5085552555          1785 First Street         None
# 32            Steve  3105553722          3675 Furth Circle         None
# 33             Rosa  2155559857          11328 Douglas Av.         None
# 34              Sue  4155554312          2793 Furth Circle         None
# 35          Valarie  6175552555             6251 Ingle Ln.         None
#
#              city state postalCode country  salesRepEmployeeNumber  \
# 0       Las Vegas    NV      83030     USA                    1166
# 1      San Rafael    CA      97562     USA                    1165
# 2   San Francisco    CA      94217     USA                    1165
# 3             NYC    NY      10022     USA                    1323
# 4             NYC    NY      10022     USA                    1286
# 5       Allentown    PA      70267     USA                    1216
# 6      Burlingame    CA      94217     USA                    1165
# 7       New Haven    CT      97823     USA                    1286
# 8       Cambridge    MA      51247     USA                    1188
# 9     Bridgewater    CT      97562     USA                    1323
# 10            NYC    NY      10022     USA                    1286
# 11     Brickhaven    MA      58339     USA                    1216
# 12     Brickhaven    MA      58339     USA                    1188
# 13       Pasadena    CA      90003     USA                    1166
# 14       Glendale    CA      92561     USA                    1166
# 15      San Diego    CA      91217     USA                    1166
# 16      Cambridge    MA      51247     USA                    1216
# 17   White Plains    NY      24067     USA                    1323
# 18    New Bedford    MA      50553     USA                    1188
# 19  San Francisco    CA      94217     USA                    1165
# 20         Newark    NJ      94019     USA                    1323
# 21   Philadelphia    PA      71270     USA                    1188
# 22    Los Angeles    CA      91003     USA                    1166
# 23         Boston    MA      51003     USA                    1216
# 24         Nashua    NH      62005     USA                    1216
# 25     Brickhaven    MA      58339     USA                    1188
# 26            NYC    NY      10022     USA                    1286
# 27       Glendale    CT      97561     USA                    1323
# 28       San Jose    CA      94217     USA                    1165
# 29      New Haven    CT      97823     USA                    1286
# 30            NYC    NY      10022     USA                    1286
# 31    New Bedford    MA      50553     USA                    1216
# 32        Burbank    CA      94019     USA                    1166
# 33   Philadelphia    PA      71270     USA                    1323
# 34       Brisbane    CA      94217     USA                    1165
# 35         Boston    MA      51003     USA                    1188
#
#     creditLimit
# 0         71800
# 1        210500
# 2         64600
# 3        114900
# 4        138500
# 5        100600
# 6         84600
# 7             0
# 8         43400
# 9         84300
# 10        76400
# 11        23000
# 12        68700
# 13        90700
# 14        11000
# 15       105000
# 16       123700
# 17       102700
# 18        94500
# 19       105000
# 20        43000
# 21        81100
# 22        57700
# 23        41900
# 24       114200
# 25        70700
# 26        67500
# 27        49700
# 28        77600
# 29        95400
# 30        39800
# 31        85800
# 32        55400
# 33        72600
# 34        60300
# 35        85100

# %% [markdown]
# **Tâche 3:** Retrieve all customers whose credit limit is above 10,000.

# %%
pd.read_sql("?", conn)

# %%
pd.read_sql('SELECT * FROM customers WHERE 	creditLimit > 10000', conn)
# Out:
#     customerNumber                    customerName contactLastName  \
# 0              103               Atelier graphique         Schmitt
# 1              112              Signal Gift Stores            King
# 2              114      Australian Collectors, Co.        Ferguson
# 3              119               La Rochelle Gifts         Labrune
# 4              121              Baane Mini Imports      Bergulfsen
# ..             ...                             ...             ...
# 93             486    Motor Mint Distributors Inc.         Salazar
# 94             487        Signal Collectibles Ltd.          Taylor
# 95             489  Double Decker Gift Stores, Ltd           Smith
# 96             495            Diecast Collectables          Franco
# 97             496                Kellys Gift Shop         Snowden
#
#    contactFirstName           phone                  addressLine1  \
# 0           Carine       40.32.2555                54, rue Royale
# 1              Jean      7025551838               8489 Strong St.
# 2             Peter    03 9520 4555             636 St Kilda Road
# 3           Janine       40.67.8555  67, rue des Cinquante Otages
# 4            Jonas       07-98 9555        Erling Skakkes gate 78
# ..              ...             ...                           ...
# 93             Rosa      2155559857             11328 Douglas Av.
# 94              Sue      4155554312             2793 Furth Circle
# 95          Thomas   (171) 555-7555               120 Hanover Sq.
# 96          Valarie      6175552555                6251 Ingle Ln.
# 97             Tony   +64 9 5555500              Arenales 1938 3A
#
#    addressLine2          city     state postalCode      country  \
# 0          None        Nantes      None      44000       France
# 1          None     Las Vegas        NV      83030          USA
# 2       Level 3     Melbourne  Victoria       3004    Australia
# 3          None        Nantes      None      44000       France
# 4          None       Stavern      None       4110       Norway
# ..          ...           ...       ...        ...          ...
# 93         None  Philadelphia        PA      71270          USA
# 94         None      Brisbane        CA      94217          USA
# 95         None        London      None    WA1 1DP           UK
# 96         None        Boston        MA      51003          USA
# 97         None    Auckland        None       None  New Zealand
#
#     salesRepEmployeeNumber  creditLimit
# 0                     1370        21000
# 1                     1166        71800
# 2                     1611       117300
# 3                     1370       118200
# 4                     1504        81700
# ..                     ...          ...
# 93                    1323        72600
# 94                    1165        60300
# 95                    1501        43300
# 96                    1188        85100
# 97                    1612       110000
#
# [98 rows x 13 columns]

# %% [markdown]
# **Tâche 4:** Retrieve customer names and countries, order them by country name.

# %%
pd.read_sql('SELECT customerName, country FROM customers ORDER BY country ASC;', conn)
# Out:
#                      customerName    country
# 0      Australian Collectors, Co.  Australia
# 1          Annas Decorations, Ltd  Australia
# 2       Souveniers And Things Co.  Australia
# 3     Australian Gift Network, Co  Australia
# 4    Australian Collectables, Ltd  Australia
# ..                            ...        ...
# 117              FunGiftIdeas.com        USA
# 118   West Coast Collectables Co.        USA
# 119  Motor Mint Distributors Inc.        USA
# 120      Signal Collectibles Ltd.        USA
# 121          Diecast Collectables        USA
#
# [122 rows x 2 columns]

# %% [markdown]
# **Tâche 5:** Retrieve the first 10 customers when ordered by name.

# %%
pd.read_sql('SELECT customerName FROM customers ORDER BY customerName ASC LIMIT 10;', conn)
# Out:
#                  customerName
# 0               ANG Resellers
# 1              AV Stores, Co.
# 2                Alpha Cognac
# 3      American Souvenirs Inc
# 4          Amica Models & Co.
# 5      Annas Decorations, Ltd
# 6         Anton Designs, Ltd.
# 7  Asian Shopping Network, Co
# 8       Asian Treasures, Inc.
# 9           Atelier graphique

# %% [markdown]
# **Tâche 6:** Find the total number of customers in the database.

# %%
pd.read_sql('SELECT COUNT(*) as total_customers FROM customers;', conn)
# Out:
#    total_customers
# 0              122

# %% [markdown]
# **Tâche 7:** Find the maximum credit limit among all customers.

# %%
pd.read_sql('SELECT MAX(creditLimit) as max_credit_limit FROM customers;', conn)
# Out:
#    max_credit_limit
# 0            227600

# %% [markdown]
# **Tâche 8:** Retrieve customer names and cities, but only those located in states that are not NULL.

# %%
pd.read_sql('SELECT customerName, city FROM customers WHERE state IS NOT NULL;', conn)
# Out:
#                          customerName            city
# 0                  Signal Gift Stores       Las Vegas
# 1          Australian Collectors, Co.       Melbourne
# 2        Mini Gifts Distributors Ltd.      San Rafael
# 3                     Mini Wheels Co.   San Francisco
# 4                   Land of Toys Inc.             NYC
# 5                  Muscle Machine Inc             NYC
# 6               Diecast Classics Inc.       Allentown
# 7                Technics Stores Inc.      Burlingame
# 8              American Souvenirs Inc       New Haven
# 9          Cambridge Collectables Co.       Cambridge
# 10                    Gift Depot Inc.     Bridgewater
# 11               Osaka Souveniers Co.         Kita-ku
# 12                    Vitachrome Inc.             NYC
# 13            Auto-Moto Classics Inc.      Brickhaven
# 14     Canadian Gift Exchange Network       Vancouver
# 15           Online Mini Collectables      Brickhaven
# 16                  Toys4GrownUps.com        Pasadena
# 17                  Boards & Toys Co.        Glendale
# 18       Québec Home Shopping Network        Montréal
# 19       Collectable Mini Designs Co.       San Diego
# 20                  giftsbymail.co.uk           Cowes
# 21  Royal Canadian Collectables, Ltd.       Tsawassen
# 22             Annas Decorations, Ltd    North Sydney
# 23          Souveniers And Things Co.       Chatswood
# 24                Martas Replicas Co.       Cambridge
# 25                      Mini Classics    White Plains
# 26                Mini Creations Ltd.     New Bedford
# 27           Corporate Gift Ideas Co.   San Francisco
# 28            Tekni Collectables Inc.          Newark
# 29        Australian Gift Network, Co  South Brisbane
# 30            Classic Gift Ideas, Inc    Philadelphia
# 31           Men R US Retailers, Ltd.     Los Angeles
# 32              Asian Treasures, Inc.            Cork
# 33               SAR Distributors, Co        Hatfield
# 34                  Gifts4AllAges.com          Boston
# 35       Online Diecast Creations Co.          Nashua
# 36         Collectables For Less Inc.      Brickhaven
# 37            Tokyo Collectables, Ltd       Minato-ku
# 38               Classic Legends Inc.             NYC
# 39                   Gift Ideas Corp.        Glendale
# 40          The Sharp Gifts Warehouse        San Jose
# 41                   Super Scale Inc.       New Haven
# 42                    Microscale Inc.             NYC
# 43                   FunGiftIdeas.com     New Bedford
# 44       Australian Collectables, Ltd    Glen Waverly
# 45        West Coast Collectables Co.         Burbank
# 46       Motor Mint Distributors Inc.    Philadelphia
# 47           Signal Collectibles Ltd.        Brisbane
# 48               Diecast Collectables          Boston

# %% [markdown]
# **Tâche 9:** Find all distinct countries where customers are located.

# %%
pd.read_sql('SELECT DISTINCT country FROM customers;', conn)
# Out:
#          country
# 0         France
# 1            USA
# 2      Australia
# 3         Norway
# 4         Poland
# 5        Germany
# 6          Spain
# 7         Sweden
# 8        Denmark
# 9      Singapore
# 10      Norway
# 11      Portugal
# 12         Japan
# 13       Finland
# 14            UK
# 15       Ireland
# 16        Canada
# 17     Hong Kong
# 18         Italy
# 19   Switzerland
# 20   Netherlands
# 21       Belgium
# 22   New Zealand
# 23  South Africa
# 24       Austria
# 25   Philippines
# 26        Russia
# 27        Israel

# %% [markdown]
# **Tâche 10:** Retrieve customer name and credit limit, for those customers with credit limits between 5000 and 15000.

# %%
pd.read_sql('SELECT customerName, creditLimit FROM customers WHERE creditLimit BETWEEN 5000 AND 15000;', conn)
# Out:
#         customerName  creditLimit
# 0  Boards & Toys Co.        11000

# %% [markdown]
# # INTERMEDIATE LEVEL

# %% [markdown]
# **Tâche 11:** Retrieve all customer names along with the name of their sales representative.
#
# Note: Adjust column names based on the 'employees' table schema.

# %%
# Query to retrieve customer names and their sales representatives' names
pd.read_sql('''
SELECT
    customers.customerName,
    employees.firstName || ' ' || employees.lastName AS salesRepName
FROM
    customers
JOIN
    employees
ON
    customers.salesRepEmployeeNumber = employees.employeeNumber;
''',conn)
# Out:
#                       customerName      salesRepName
# 0                Atelier graphique  Gerard Hernandez
# 1               Signal Gift Stores   Leslie Thompson
# 2       Australian Collectors, Co.       Andy Fixter
# 3                La Rochelle Gifts  Gerard Hernandez
# 4               Baane Mini Imports       Barry Jones
# ..                             ...               ...
# 95    Motor Mint Distributors Inc.     George Vanauf
# 96        Signal Collectibles Ltd.   Leslie Jennings
# 97  Double Decker Gift Stores, Ltd        Larry Bott
# 98            Diecast Collectables    Julie Firrelli
# 99                Kellys Gift Shop       Peter Marsh
#
# [100 rows x 2 columns]

# %% [markdown]
# **Tâche 12:** Retrieve countries and count of customers in each, only for countries having more than 5 customers.

# %%
# Query to retrieve countries and count of customers for countries having more than 5 customers
pd.read_sql( '''
SELECT
    country,
    COUNT(*) AS customer_count
FROM
    customers
GROUP BY
    country
HAVING
    COUNT(*) > 5;
''',conn)
# Out:
#    country  customer_count
# 0   France              12
# 1  Germany              13
# 2    Spain               7
# 3      USA              36

# %% [markdown]
# **Tâche 13:** Retrieve the total credit limit per country, ordering by total credit limit descending.

# %%
# Query to retrieve the total credit limit per country, ordering by total credit limit descending
pd.read_sql( '''
SELECT
    country,
    SUM(creditLimit) AS total_credit_limit
FROM
    customers
GROUP BY
    country
ORDER BY
    total_credit_limit DESC;
''', conn)
# Out:
#          country  total_credit_limit
# 0            USA             2811700
# 1         France              932300
# 2          Spain              517800
# 3             UK              443700
# 4      Australia              430300
# 5          Italy              388800
# 6    New Zealand              362500
# 7        Finland              285800
# 8        Germany              257100
# 9         Canada              228600
# 10       Denmark              204200
# 11     Singapore              201700
# 12      Norway                191900
# 13         Japan              175600
# 14        Sweden              169500
# 15   Switzerland              141300
# 16       Austria              117000
# 17       Belgium              103400
# 18        Norway               81700
# 19   Philippines               81500
# 20       Ireland               69400
# 21     Hong Kong               58600
# 22  South Africa                   0
# 23        Russia                   0
# 24      Portugal                   0
# 25        Poland                   0
# 26   Netherlands                   0
# 27        Israel                   0

# %% [markdown]
# **Tâche 14:** Retrieve the average credit limit and count of customers, grouped by country and state.

# %%
# Query to retrieve the average credit limit and count of customers, grouped by country and state
pd.read_sql('''
SELECT
    country,
    state,
    AVG(creditLimit) AS average_credit_limit,
    COUNT(*) AS customer_count
FROM
    customers
GROUP BY
    country,
    state;
''', conn)
# Out:
#          country          state  average_credit_limit  customer_count
# 0      Australia            NSW         100550.000000               2
# 1      Australia     Queensland          51600.000000               1
# 2      Australia       Victoria          88800.000000               2
# 3        Austria           None          58500.000000               2
# 4        Belgium           None          51700.000000               2
# 5         Canada             BC          89950.000000               2
# 6         Canada         Québec          48700.000000               1
# 7        Denmark           None         102100.000000               2
# 8        Finland           None          95266.666667               3
# 9         France           None          77691.666667              12
# 10       Germany           None          19776.923077              13
# 11     Hong Kong           None          58600.000000               1
# 12       Ireland           None          69400.000000               1
# 13       Ireland       Co. Cork              0.000000               1
# 14        Israel           None              0.000000               1
# 15         Italy           None          97200.000000               4
# 16         Japan          Osaka          81200.000000               1
# 17         Japan          Tokyo          94400.000000               1
# 18   Netherlands           None              0.000000               1
# 19   New Zealand           None          90625.000000               4
# 20        Norway           None          81700.000000               1
# 21      Norway             None          95950.000000               2
# 22   Philippines           None          81500.000000               1
# 23        Poland           None              0.000000               1
# 24      Portugal           None              0.000000               2
# 25        Russia           None              0.000000               1
# 26     Singapore           None          67233.333333               3
# 27  South Africa       Pretoria              0.000000               1
# 28         Spain           None          73971.428571               7
# 29        Sweden           None          84750.000000               2
# 30   Switzerland           None          47100.000000               3
# 31            UK           None          87450.000000               4
# 32            UK  Isle of Wight          93900.000000               1
# 33           USA             CA          83854.545455              11
# 34           USA             CT          57350.000000               4
# 35           USA             MA          70755.555556               9
# 36           USA             NH         114200.000000               1
# 37           USA             NJ          43000.000000               1
# 38           USA             NV          71800.000000               1
# 39           USA             NY          89966.666667               6
# 40           USA             PA          84766.666667               3

# %% [markdown]
# **Tâche 15:** Retrieve the customer with the minimum credit limit in the USA.

# %%
# Query to retrieve the customer with the minimum credit limit in the USA
pd.read_sql('''
SELECT
    customerName,
    creditLimit
FROM
    customers
WHERE
    country = 'USA'
ORDER BY
    creditLimit ASC
LIMIT 1;
''', conn)
# Out:
#              customerName  creditLimit
# 0  American Souvenirs Inc            0

# %% [markdown]
# **Tâche 16:** Retrieve customer names and their sales representative names, but only for customers with a NULL state.

# %%
# Note: Adjust column names based on the 'employees' table schema.
# Query to retrieve customer names and their sales representative names, where state is NULL
pd.read_sql('''
SELECT
    customers.customerName,
    employees.firstName || ' ' || employees.lastName AS salesRepName
FROM
    customers
JOIN
    employees
ON
    customers.salesRepEmployeeNumber = employees.employeeNumber
WHERE
    customers.state IS NULL;
''',conn)
# Out:
#                           customerName      salesRepName
# 0                    Atelier graphique  Gerard Hernandez
# 1                    La Rochelle Gifts  Gerard Hernandez
# 2                   Baane Mini Imports       Barry Jones
# 3                 Blauer See Auto, Co.       Barry Jones
# 4               Euro+ Shopping Channel  Gerard Hernandez
# 5             Volvo Model Replicas, Co       Barry Jones
# 6             Danish Wholesale Imports   Pamela Castillo
# 7               Saveley & Henriot, Co.       Loui Bondur
# 8              Dragon Souveniers, Ltd.        Mami Nishi
# 9                     Handji Gifts& Co       Peter Marsh
# 10                        Herkku Gifts       Barry Jones
# 11            Daedalus Designs Imports  Gerard Hernandez
# 12            La Corne Dabondance, Co.       Loui Bondur
# 13                Toys of Finland, Co.        Larry Bott
# 14                      AV Stores, Co.        Larry Bott
# 15             Clover Collections, Co.       Barry Jones
# 16               UK Collectables, Ltd.        Larry Bott
# 17                         Mini Caravy  Gerard Hernandez
# 18         King Kong Collectables, Co.        Mami Nishi
# 19                  Enaco Distributors     Martin Gerard
# 20                Heintze Collectables   Pamela Castillo
# 21                        Alpha Cognac  Gerard Hernandez
# 22                  Amica Models & Co.   Pamela Castillo
# 23                     Lyon Souveniers       Loui Bondur
# 24                Auto Associés & Cie.  Gerard Hernandez
# 25             Toms Spezialitäten, Ltd       Barry Jones
# 26                       Rovelli Gifts   Pamela Castillo
# 27                     Vida Sport, Ltd     Martin Gerard
# 28           Norway Gifts By Mail, Co.       Barry Jones
# 29             Oulu Toy Supplies, Inc.        Larry Bott
# 30                          Petit Auto   Pamela Castillo
# 31          Down Under Souveniers, Inc       Peter Marsh
# 32            Stylish Desk Decors, Co.        Larry Bott
# 33                 Suominen Souveniers        Larry Bott
# 34                         CAF Imports     Martin Gerard
# 35                Marseille Mini Autos       Loui Bondur
# 36                  Reims Collectables       Loui Bondur
# 37                     GiftsForHim.com       Peter Marsh
# 38               Precious Collectables     Martin Gerard
# 39                        Royale Belge   Pamela Castillo
# 40               Salzburg Collectables   Pamela Castillo
# 41                     Cruz & Sons Co.        Mami Nishi
# 42                  Lordine Souveniers   Pamela Castillo
# 43                   Auto Canal+ Petit       Loui Bondur
# 44       Extreme Desk Decorations, Ltd       Peter Marsh
# 45  Bavarian Collectables Imports, Co.       Barry Jones
# 46             Scandinavian Gift Ideas       Barry Jones
# 47                     Mini Auto Werke   Pamela Castillo
# 48          Corrida Auto Replicas, Ltd     Martin Gerard
# 49                  Frau da Collezione   Pamela Castillo
# 50          Iberia Gift Imports, Corp.     Martin Gerard
# 51      Double Decker Gift Stores, Ltd        Larry Bott
# 52                    Kellys Gift Shop       Peter Marsh

# %% [markdown]
# **Tâche 17:** Retrieve the top 5 countries with the highest average credit limit.

# %%
# Query to retrieve the top 5 countries with the highest average credit limit
pd.read_sql('''
SELECT
    country,
    AVG(creditLimit) AS average_credit_limit
FROM
    customers
GROUP BY
    country
ORDER BY
    average_credit_limit DESC
LIMIT 5;
''', conn)
# Out:
#        country  average_credit_limit
# 0      Denmark         102100.000000
# 1        Italy          97200.000000
# 2     Norway            95950.000000
# 3      Finland          95266.666667
# 4  New Zealand          90625.000000

# %% [markdown]
# **Tâche 18:** Retrieve customer names that start with "A" and are located in the USA.

# %%
# Query to retrieve customer names that start with "A" and are located in the USA
pd.read_sql('''
SELECT
    customerName
FROM
    customers
WHERE
    customerName LIKE 'A%'
    AND country = 'USA';
''', conn)
# Out:
#               customerName
# 0   American Souvenirs Inc
# 1  Auto-Moto Classics Inc.

# %% [markdown]
# **Tâche 19:** Retrieve customer names and their sales representative numbers, for customers without a sales representative.

# %%
# Query to retrieve customer names and their sales representative numbers for customers without a sales representative
pd.read_sql('''
SELECT
    customerName,
    salesRepEmployeeNumber
FROM
    customers
WHERE
    salesRepEmployeeNumber IS NULL;
''', conn)
# Out:
#                       customerName salesRepEmployeeNumber
# 0               Havel & Zbyszek Co                   None
# 1                Porto Imports Co.                   None
# 2       Asian Shopping Network, Co                   None
# 3                  Natürlich Autos                   None
# 4                    ANG Resellers                   None
# 5         Messner Shopping Network                   None
# 6                Franken Gifts, Co                   None
# 7                BG&E Collectables                   None
# 8                 Schuyler Imports                   None
# 9                 Der Hund Imports                   None
# 10       Cramer Spezialitäten, Ltd                   None
# 11           Asian Treasures, Inc.                   None
# 12            SAR Distributors, Co                   None
# 13                 Kommission Auto                   None
# 14          Lisboa Souveniers, Inc                   None
# 15  Stuttgart Collectable Exchange                   None
# 16        Feuer Online Stores, Inc                   None
# 17                Warburg Exchange                   None
# 18             Anton Designs, Ltd.                   None
# 19             Mit Vergnügen & Co.                   None
# 20       Kremlin Collectables, Co.                   None
# 21              Raanan Stores, Inc                   None

# %% [markdown]
# **Tâche 20:** Retrieve the second set of 10 customers when ordered by name.

# %%
# Query to retrieve the second set of 10 customers ordered by name
pd.read_sql('''
SELECT
    customerName
FROM
    customers
ORDER BY
    customerName
LIMIT 10
OFFSET 10;
''', conn)
# Out:
#                          customerName
# 0        Australian Collectables, Ltd
# 1          Australian Collectors, Co.
# 2         Australian Gift Network, Co
# 3                Auto Associés & Cie.
# 4                   Auto Canal+ Petit
# 5             Auto-Moto Classics Inc.
# 6                   BG&E Collectables
# 7                  Baane Mini Imports
# 8  Bavarian Collectables Imports, Co.
# 9                Blauer See Auto, Co.

# %% [markdown]
# # ADVANCED LEVEL

# %% [markdown]
# **Tâche 21:** Find customer names with the highest credit limit.

# %%
# Query to find the highest credit limit
pd.read_sql('''
SELECT
    customerName,
    creditLimit
FROM
    customers
WHERE
    creditLimit = (SELECT MAX(creditLimit) FROM customers);
''', conn)
# Out:
#              customerName  creditLimit
# 0  Euro+ Shopping Channel       227600

# %% [markdown]
# **Tâche 22:** Retrieve customer names and their credit limit, omitting customers with the lowest credit limit.

# %%
# Query to retrieve customer names and credit limits, omitting customers with the lowest credit limit
pd.read_sql('''
SELECT
    customerName,
    creditLimit
FROM
    customers
WHERE
    creditLimit > (SELECT MIN(creditLimit) FROM customers);
''', conn)
# Out:
#                       customerName  creditLimit
# 0                Atelier graphique        21000
# 1               Signal Gift Stores        71800
# 2       Australian Collectors, Co.       117300
# 3                La Rochelle Gifts       118200
# 4               Baane Mini Imports        81700
# ..                             ...          ...
# 93    Motor Mint Distributors Inc.        72600
# 94        Signal Collectibles Ltd.        60300
# 95  Double Decker Gift Stores, Ltd        43300
# 96            Diecast Collectables        85100
# 97                Kellys Gift Shop       110000
#
# [98 rows x 2 columns]

# %% [markdown]
# **Tâche 24:** Retrieve customer names with a credit limit below the average and order them by credit limit ascending.

# %%
# Query to retrieve customer names with credit limit below the average, ordered by credit limit ascending
pd.read_sql('''
SELECT
    customerName,
    creditLimit
FROM
    customers
WHERE
    creditLimit < (SELECT AVG(creditLimit) FROM customers)
ORDER BY
    creditLimit ASC;
''', conn)
# Out:
#                       customerName  creditLimit
# 0               Havel & Zbyszek Co            0
# 1           American Souvenirs Inc            0
# 2                Porto Imports Co.            0
# 3       Asian Shopping Network, Co            0
# 4                  Natürlich Autos            0
# 5                    ANG Resellers            0
# 6         Messner Shopping Network            0
# 7                Franken Gifts, Co            0
# 8                BG&E Collectables            0
# 9                 Schuyler Imports            0
# 10                Der Hund Imports            0
# 11       Cramer Spezialitäten, Ltd            0
# 12           Asian Treasures, Inc.            0
# 13            SAR Distributors, Co            0
# 14                 Kommission Auto            0
# 15          Lisboa Souveniers, Inc            0
# 16           Precious Collectables            0
# 17  Stuttgart Collectable Exchange            0
# 18        Feuer Online Stores, Inc            0
# 19                Warburg Exchange            0
# 20             Anton Designs, Ltd.            0
# 21             Mit Vergnügen & Co.            0
# 22       Kremlin Collectables, Co.            0
# 23              Raanan Stores, Inc            0
# 24               Boards & Toys Co.        11000
# 25               Atelier graphique        21000
# 26         Auto-Moto Classics Inc.        23000
# 27                    Royale Belge        23500
# 28              Frau da Collezione        34800
# 29                 Microscale Inc.        39800
# 30               Gifts4AllAges.com        41900
# 31         Tekni Collectables Inc.        43000
# 32  Double Decker Gift Stores, Ltd        43300
# 33      Cambridge Collectables Co.        43400
# 34                 Mini Auto Werke        45300
# 35    Québec Home Shopping Network        48700
# 36                Gift Ideas Corp.        49700
# 37     Australian Gift Network, Co        51600
# 38        Volvo Model Replicas, Co        53100
# 39                     Mini Caravy        53800
# 40     West Coast Collectables Co.        55400
# 41        Men R US Retailers, Ltd.        57700
# 42     King Kong Collectables, Co.        58600
# 43                     CAF Imports        59600
# 44            Blauer See Auto, Co.        59700
# 45              Enaco Distributors        60300
# 46    Australian Collectables, Ltd        60300
# 47        Signal Collectibles Ltd.        60300
# 48                    Alpha Cognac        61100
# 49                 Mini Wheels Co.        64600
# 50            Marseille Mini Autos        65000
# 51      Iberia Gift Imports, Corp.        65700
# 52            Classic Legends Inc.        67500

# %% [markdown]
# **Tâche 25:** Retrieve customer name and total credit limit, but only for customers with a sales representative.

# %%
# Ensure that the result is ordered by total credit limit descending.
# Query to retrieve customer name and credit limit for customers with a sales representative
pd.read_sql('''
SELECT
    customerName,
    creditLimit
FROM
    customers
WHERE
    salesRepEmployeeNumber IS NOT NULL;
''', conn)
# Out:
#                       customerName  creditLimit
# 0                Atelier graphique        21000
# 1               Signal Gift Stores        71800
# 2       Australian Collectors, Co.       117300
# 3                La Rochelle Gifts       118200
# 4               Baane Mini Imports        81700
# ..                             ...          ...
# 95    Motor Mint Distributors Inc.        72600
# 96        Signal Collectibles Ltd.        60300
# 97  Double Decker Gift Stores, Ltd        43300
# 98            Diecast Collectables        85100
# 99                Kellys Gift Shop       110000
#
# [100 rows x 2 columns]

# %% [markdown]
# **Tâche 26:** Retrieve the third highest credit limit from all customers.

# %%
# Query to retrieve the third highest credit limit
pd.read_sql('''
SELECT
    creditLimit
FROM
    customers
ORDER BY
    creditLimit DESC
LIMIT 1
OFFSET 2;
''', conn)
# Out:
#    creditLimit
# 0       141300

# %% [markdown]
# **Tâche 27:** Retrieve customer names and their credit limit, ordering first by country ascending and then by credit limit descending.

# %%
# Query to retrieve customer names and their credit limit, ordering by country ASC and credit limit DESC
pd.read_sql('''
SELECT
    customerName,
    country,
    creditLimit
FROM
    customers
ORDER BY
    country ASC,
    creditLimit DESC;
''', conn)
# Out:
#                      customerName    country  creditLimit
# 0      Australian Collectors, Co.  Australia       117300
# 1          Annas Decorations, Ltd  Australia       107800
# 2       Souveniers And Things Co.  Australia        93300
# 3    Australian Collectables, Ltd  Australia        60300
# 4     Australian Gift Network, Co  Australia        51600
# ..                            ...        ...          ...
# 117             Gifts4AllAges.com        USA        41900
# 118               Microscale Inc.        USA        39800
# 119       Auto-Moto Classics Inc.        USA        23000
# 120             Boards & Toys Co.        USA        11000
# 121        American Souvenirs Inc        USA            0
#
# [122 rows x 3 columns]

# %% [markdown]
# **Tâche 29:** Retrieve customer names who have a credit limit higher than the average credit limit of all customers.

# %%
# Query to retrieve customer names with credit limit higher than the average credit limit
pd.read_sql('''
SELECT
    customerName,
    creditLimit
FROM
    customers
WHERE
    creditLimit > (SELECT AVG(creditLimit) FROM customers);
''', conn)
# Out:
#                     customerName  creditLimit
# 0             Signal Gift Stores        71800
# 1     Australian Collectors, Co.       117300
# 2              La Rochelle Gifts       118200
# 3             Baane Mini Imports        81700
# 4   Mini Gifts Distributors Ltd.       210500
# ..                           ...          ...
# 64    Corrida Auto Replicas, Ltd       104600
# 65              FunGiftIdeas.com        85800
# 66  Motor Mint Distributors Inc.        72600
# 67          Diecast Collectables        85100
# 68              Kellys Gift Shop       110000
#
# [69 rows x 2 columns]

# %% [markdown]
# # Pro LEVEL

# %% [markdown]
# **Tâche 30:** Retrieve the customer name, country, and credit limit, but only for customers with a credit limit above the average per country.

# %%
#  to retrieve customer name, country, and credit limit for customers with credit limit above average per country
pd.read_sql( '''
SELECT
    customerName,
    country,
    creditLimit
FROM
    customers
WHERE
    creditLimit > (
        SELECT AVG(creditLimit)
        FROM customers AS avg_customers
        WHERE avg_customers.country = customers.country
    );
''',conn)
# Out:
#                           customerName      country  creditLimit
# 0           Australian Collectors, Co.    Australia       117300
# 1                    La Rochelle Gifts       France       118200
# 2         Mini Gifts Distributors Ltd.          USA       210500
# 3                 Blauer See Auto, Co.      Germany        59700
# 4                    Land of Toys Inc.          USA       114900
# 5               Euro+ Shopping Channel        Spain       227600
# 6               Saveley & Henriot, Co.       France       123900
# 7              Dragon Souveniers, Ltd.    Singapore       103800
# 8                   Muscle Machine Inc          USA       138500
# 9                Diecast Classics Inc.          USA       100600
# 10                Technics Stores Inc.          USA        84600
# 11                    Handji Gifts& Co    Singapore        97900
# 12                        Herkku Gifts     Norway          96800
# 13            Daedalus Designs Imports       France        82900
# 14            La Corne Dabondance, Co.       France        84300
# 15                     Gift Depot Inc.          USA        84300
# 16                Toys of Finland, Co.      Finland        96500
# 17                      AV Stores, Co.           UK       136800
# 18             Clover Collections, Co.      Ireland        69400
# 19               UK Collectables, Ltd.           UK        92700
# 20      Canadian Gift Exchange Network       Canada        90300
# 21                   Toys4GrownUps.com          USA        90700
# 22                Heintze Collectables      Denmark       120800
# 23        Collectable Mini Designs Co.          USA       105000
# 24                   giftsbymail.co.uk           UK        93900
# 25                  Amica Models & Co.        Italy       113000
# 26                Auto Associés & Cie.       France        77900
# 27             Toms Spezialitäten, Ltd      Germany       120400
# 28   Royal Canadian Collectables, Ltd.       Canada        89600
# 29              Annas Decorations, Ltd    Australia       107800
# 30                       Rovelli Gifts        Italy       119600
# 31           Souveniers And Things Co.    Australia        93300
# 32                 Martas Replicas Co.          USA       123700
# 33                     Vida Sport, Ltd  Switzerland       141300
# 34                          Petit Auto      Belgium        79900
# 35                       Mini Classics          USA       102700
# 36                 Mini Creations Ltd.          USA        94500
# 37            Corporate Gift Ideas Co.          USA       105000
# 38                 Suominen Souveniers      Finland        98800
# 39             Classic Gift Ideas, Inc          USA        81100
# 40                  Reims Collectables       France        81100
# 41        Online Diecast Creations Co.          USA       114200
# 42               Salzburg Collectables      Austria        71700
# 43                  Lordine Souveniers        Italy       121400
# 44             Tokyo Collectables, Ltd        Japan        94400
# 45                   Auto Canal+ Petit       France        95000
# 46  Bavarian Collectables Imports, Co.      Germany        77000
# 47             Scandinavian Gift Ideas       Sweden       116400
# 48                    Super Scale Inc.          USA        95400
# 49          Corrida Auto Replicas, Ltd        Spain       104600
# 50                    FunGiftIdeas.com          USA        85800
# 51                Diecast Collectables          USA        85100
# 52                    Kellys Gift Shop  New Zealand       110000

# %% [markdown]
# **Tâche 31:** Use the LAG() function to retrieve the customer name along with the credit limit difference from the previous customer, ordered by credit limit.

# %%
  # Query to retrieve customer name and credit limit difference from the previous customer, ordered by credit limit
pd.read_sql('''
SELECT
    customerName,
    creditLimit,
    creditLimit - LAG(creditLimit, 1) OVER (ORDER BY creditLimit) AS creditLimitDifference
FROM
    customers
ORDER BY
    creditLimit;
''', conn)
# Out:
#                      customerName  creditLimit  creditLimitDifference
# 0              Havel & Zbyszek Co            0                    NaN
# 1          American Souvenirs Inc            0                    0.0
# 2               Porto Imports Co.            0                    0.0
# 3      Asian Shopping Network, Co            0                    0.0
# 4                 Natürlich Autos            0                    0.0
# ..                            ...          ...                    ...
# 117                AV Stores, Co.       136800                12900.0
# 118            Muscle Machine Inc       138500                 1700.0
# 119               Vida Sport, Ltd       141300                 2800.0
# 120  Mini Gifts Distributors Ltd.       210500                69200.0
# 121        Euro+ Shopping Channel       227600                17100.0
#
# [122 rows x 3 columns]

# %% [markdown]
# **Tâche 32:** Use the RANK() function to retrieve the customer name, credit limit, and a rank column that ranks customers based on their credit limit.

# %%
# Query to retrieve customer name, credit limit, and rank based on credit limit
pd.read_sql( '''
SELECT
    customerName,
    creditLimit,
    RANK() OVER (ORDER BY creditLimit DESC) AS rank
FROM
    customers
ORDER BY
    creditLimit DESC;
''', conn)
# Out:
#                      customerName  creditLimit  rank
# 0          Euro+ Shopping Channel       227600     1
# 1    Mini Gifts Distributors Ltd.       210500     2
# 2                 Vida Sport, Ltd       141300     3
# 3              Muscle Machine Inc       138500     4
# 4                  AV Stores, Co.       136800     5
# ..                            ...          ...   ...
# 117              Warburg Exchange            0    99
# 118           Anton Designs, Ltd.            0    99
# 119           Mit Vergnügen & Co.            0    99
# 120     Kremlin Collectables, Co.            0    99
# 121            Raanan Stores, Inc            0    99
#
# [122 rows x 3 columns]

# %% [markdown]
# **Tâche 33:** Use NTILE to divide the customers into 4 groups based on their credit limit.

# %%
# Query to divide customers into 4 groups based on their credit limit
pd.read_sql('''
SELECT
    customerName,
    creditLimit,
    NTILE(4) OVER (ORDER BY creditLimit DESC) AS creditLimitGroup
FROM
    customers
ORDER BY
    creditLimit DESC;
''', conn)
# Out:
#                      customerName  creditLimit  creditLimitGroup
# 0          Euro+ Shopping Channel       227600                 1
# 1    Mini Gifts Distributors Ltd.       210500                 1
# 2                 Vida Sport, Ltd       141300                 1
# 3              Muscle Machine Inc       138500                 1
# 4                  AV Stores, Co.       136800                 1
# ..                            ...          ...               ...
# 117              Warburg Exchange            0                 4
# 118           Anton Designs, Ltd.            0                 4
# 119           Mit Vergnügen & Co.            0                 4
# 120     Kremlin Collectables, Co.            0                 4
# 121            Raanan Stores, Inc            0                 4
#
# [122 rows x 3 columns]

# %% [markdown]
# **Tâche 34:** Use PARTITION BY to retrieve the average credit limit per country and compare individual customer credit limits with the average.

# %%
# Query to calculate the average credit limit per country and compare it with individual credit limits
pd.read_sql('''
SELECT
    customerName,
    country,
    creditLimit,
    AVG(creditLimit) OVER (PARTITION BY country) AS avg_credit_limit_per_country,
    creditLimit - AVG(creditLimit) OVER (PARTITION BY country) AS credit_limit_difference
FROM
    customers
ORDER BY
    country;
''', conn)
# Out:
#                      customerName    country  creditLimit  \
# 0      Australian Collectors, Co.  Australia       117300
# 1          Annas Decorations, Ltd  Australia       107800
# 2       Souveniers And Things Co.  Australia        93300
# 3     Australian Gift Network, Co  Australia        51600
# 4    Australian Collectables, Ltd  Australia        60300
# ..                            ...        ...          ...
# 117              FunGiftIdeas.com        USA        85800
# 118   West Coast Collectables Co.        USA        55400
# 119  Motor Mint Distributors Inc.        USA        72600
# 120      Signal Collectibles Ltd.        USA        60300
# 121          Diecast Collectables        USA        85100
#
#      avg_credit_limit_per_country  credit_limit_difference
# 0                    86060.000000             31240.000000
# 1                    86060.000000             21740.000000
# 2                    86060.000000              7240.000000
# 3                    86060.000000            -34460.000000
# 4                    86060.000000            -25760.000000
# ..                            ...                      ...
# 117                  78102.777778              7697.222222
# 118                  78102.777778            -22702.777778
# 119                  78102.777778             -5502.777778
# 120                  78102.777778            -17802.777778
# 121                  78102.777778              6997.222222
#
# [122 rows x 5 columns]

# %% [markdown]
# **Tâche 35:** Use ROW_NUMBER() to assign a unique sequential integer to customers ordered by credit limit, and filter to retrieve only the top 10 customers.

# %%
# Query to assign a unique sequential integer to customers ordered by credit limit, and retrieve only the top 10
pd.read_sql('''
WITH RankedCustomers AS (
    SELECT
        customerName,
        creditLimit,
        ROW_NUMBER() OVER (ORDER BY creditLimit DESC) AS row_num
    FROM
        customers
)
SELECT
    customerName,
    creditLimit,
    row_num
FROM
    RankedCustomers
WHERE
    row_num <= 10;
''',conn)
# Out:
#                    customerName  creditLimit  row_num
# 0        Euro+ Shopping Channel       227600        1
# 1  Mini Gifts Distributors Ltd.       210500        2
# 2               Vida Sport, Ltd       141300        3
# 3            Muscle Machine Inc       138500        4
# 4                AV Stores, Co.       136800        5
# 5        Saveley & Henriot, Co.       123900        6
# 6           Martas Replicas Co.       123700        7
# 7            Lordine Souveniers       121400        8
# 8          Heintze Collectables       120800        9
# 9       Toms Spezialitäten, Ltd       120400       10

# %% [markdown]
# **Tâche 36:** Use FIRST_VALUE to retrieve the customer name along with the name of the customer with the highest credit limit.

# %%
# Query to retrieve customer name, credit limit, and percentile rank of credit limit
pd.read_sql('''
SELECT
    customerName,
    creditLimit,
    PERCENT_RANK() OVER (ORDER BY creditLimit ASC) AS percentile_rank
FROM
    customers
ORDER BY
    creditLimit ASC;
''', conn)
# Out:
#                      customerName  creditLimit  percentile_rank
# 0              Havel & Zbyszek Co            0         0.000000
# 1          American Souvenirs Inc            0         0.000000
# 2               Porto Imports Co.            0         0.000000
# 3      Asian Shopping Network, Co            0         0.000000
# 4                 Natürlich Autos            0         0.000000
# ..                            ...          ...              ...
# 117                AV Stores, Co.       136800         0.966942
# 118            Muscle Machine Inc       138500         0.975207
# 119               Vida Sport, Ltd       141300         0.983471
# 120  Mini Gifts Distributors Ltd.       210500         0.991736
# 121        Euro+ Shopping Channel       227600         1.000000
#
# [122 rows x 3 columns]

# %% [markdown]
# **Tâche 37:** Use PERCENT_RANK() to retrieve the customer name, credit limit, and percentile rank of the credit limit among all customers.

# %%
# Query to retrieve customer name, credit limit, and percentile rank of the credit limit
pd.read_sql('''
SELECT
    customerName,
    creditLimit,
    PERCENT_RANK() OVER (ORDER BY creditLimit ASC) AS percentile_rank
FROM
    customers
ORDER BY
    creditLimit ASC;
''', conn)
# Out:
#                      customerName  creditLimit  percentile_rank
# 0              Havel & Zbyszek Co            0         0.000000
# 1          American Souvenirs Inc            0         0.000000
# 2               Porto Imports Co.            0         0.000000
# 3      Asian Shopping Network, Co            0         0.000000
# 4                 Natürlich Autos            0         0.000000
# ..                            ...          ...              ...
# 117                AV Stores, Co.       136800         0.966942
# 118            Muscle Machine Inc       138500         0.975207
# 119               Vida Sport, Ltd       141300         0.983471
# 120  Mini Gifts Distributors Ltd.       210500         0.991736
# 121        Euro+ Shopping Channel       227600         1.000000
#
# [122 rows x 3 columns]

# %% [markdown]
# **Tâche 38:** Use the LAG() function to retrieve the customer name and the difference between the credit limit of the current customer and the one before, partitioned by country.

# %%
# Query to retrieve customer name and the difference between the current and previous customer's credit limit, partitioned by country
pd.read_sql('''
SELECT
    customerName,
    country,
    creditLimit,
    creditLimit - LAG(creditLimit, 1) OVER (PARTITION BY country ORDER BY creditLimit) AS creditLimitDifference
FROM
    customers
ORDER BY
    country, creditLimit;
''',conn)
# Out:
#                      customerName    country  creditLimit  \
# 0     Australian Gift Network, Co  Australia        51600
# 1    Australian Collectables, Ltd  Australia        60300
# 2       Souveniers And Things Co.  Australia        93300
# 3          Annas Decorations, Ltd  Australia       107800
# 4      Australian Collectors, Co.  Australia       117300
# ..                            ...        ...          ...
# 117  Online Diecast Creations Co.        USA       114200
# 118             Land of Toys Inc.        USA       114900
# 119           Martas Replicas Co.        USA       123700
# 120            Muscle Machine Inc        USA       138500
# 121  Mini Gifts Distributors Ltd.        USA       210500
#
#      creditLimitDifference
# 0                      NaN
# 1                   8700.0
# 2                  33000.0
# 3                  14500.0
# 4                   9500.0
# ..                     ...
# 117                 9200.0
# 118                  700.0
# 119                 8800.0
# 120                14800.0
# 121                72000.0
#
# [122 rows x 4 columns]

# %% [markdown]
# **Tâche 39:** Use RANK() to retrieve the customer name and ranking of the credit limit, partitioned by country.

# %%
# Query to retrieve customer name and rank of credit limit, partitioned by country
pd.read_sql('''
SELECT
    customerName,
    country,
    creditLimit,
    RANK() OVER (PARTITION BY country ORDER BY creditLimit DESC) AS creditLimitRank
FROM
    customers
ORDER BY
    country, creditLimitRank;
''', conn)
# Out:
#                      customerName    country  creditLimit  creditLimitRank
# 0      Australian Collectors, Co.  Australia       117300                1
# 1          Annas Decorations, Ltd  Australia       107800                2
# 2       Souveniers And Things Co.  Australia        93300                3
# 3    Australian Collectables, Ltd  Australia        60300                4
# 4     Australian Gift Network, Co  Australia        51600                5
# ..                            ...        ...          ...              ...
# 117             Gifts4AllAges.com        USA        41900               32
# 118               Microscale Inc.        USA        39800               33
# 119       Auto-Moto Classics Inc.        USA        23000               34
# 120             Boards & Toys Co.        USA        11000               35
# 121        American Souvenirs Inc        USA            0               36
#
# [122 rows x 4 columns]

# %% [markdown]
# **Tâche 40:** Use DENSE_RANK() to retrieve the customer name and ranking of the credit limit without gaps, partitioned by country.

# %%
# Query to retrieve customer name and dense rank of credit limit, partitioned by country
pd.read_sql('''
SELECT
    customerName,
    country,
    creditLimit,
    DENSE_RANK() OVER (PARTITION BY country ORDER BY creditLimit DESC) AS creditLimitDenseRank
FROM
    customers
ORDER BY
    country, creditLimitDenseRank;
''', conn)
# Out:
#                      customerName    country  creditLimit  \
# 0      Australian Collectors, Co.  Australia       117300
# 1          Annas Decorations, Ltd  Australia       107800
# 2       Souveniers And Things Co.  Australia        93300
# 3    Australian Collectables, Ltd  Australia        60300
# 4     Australian Gift Network, Co  Australia        51600
# ..                            ...        ...          ...
# 117             Gifts4AllAges.com        USA        41900
# 118               Microscale Inc.        USA        39800
# 119       Auto-Moto Classics Inc.        USA        23000
# 120             Boards & Toys Co.        USA        11000
# 121        American Souvenirs Inc        USA            0
#
#      creditLimitDenseRank
# 0                       1
# 1                       2
# 2                       3
# 3                       4
# 4                       5
# ..                    ...
# 117                    31
# 118                    32
# 119                    33
# 120                    34
# 121                    35
#
# [122 rows x 4 columns]
